# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import json
import dataset
import credentials
import sqlite3

# db = dataset.connect("sqlite:///tweet2.db")

class TwitterStreamer():
    
    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
        auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
        
        stream = Stream(auth, listener)
        
        stream.filter(track=['Mumbai'])
        
 
class StdOutListener(StreamListener):
    
    def on_status(self, status):
        print(status.text)

    def on_error(self, status):
        print(status)

    def on_data(self, data):
        all_data             = json.loads(data)
        created_at           = all_data['created_at']
        favorite_count       = all_data['favorite_count']
        favorited            = all_data['favorited']
        filter_level         = all_data['filter_level']
        lang                 = all_data['lang']
        retweet_count        = all_data['retweet_count']
        retweeted            = all_data['retweeted']
        source               = all_data['source']
        text                 = all_data['text']
        truncated            = all_data['truncated']
        user_created_at      = all_data['user']['created_at']
        user_followers_count = all_data['user']['followers_count']
        user_location        = all_data['user']['location']
        user_lang            = all_data['user']['lang']
        user_name            = all_data['user']['name']
        user_screen_name     = all_data['user']['screen_name']
        user_time_zone       = all_data['user']['time_zone']
        user_utc_offset      = all_data['user']['utc_offset']
        user_friends_count   = all_data['user']['friends_count']
        geo_enabled          = all_data['user']['geo_enabled']  
        coordinates          = all_data['coordinates']
        geo                  = all_data['geo']
        place                = all_data['place']
        if place is not None:
            place_name       = all_data['place']['name']
        else:
            place_name       = all_data['place']
        
        print(all_data)
    
        
        conn = sqlite3.connect('tweet2.db')
        c = conn.cursor()
        
        #c.execute("""CREATE TABLE tweets
        #(created_at, favorite_count, favorited, filter_level, lang, 
         #                retweet_count, retweeted, source, text, truncated, user_created_at,  
        #                user_followers_count, user_location, user_lang, user_name, 
        #                 user_screen_name, user_time_zone, user_friends_count,geo_enabled,geo,place_name)""")
                         
        c.execute('''INSERT INTO tweets 
        (created_at, favorite_count, favorited, filter_level, lang, 
                         retweet_count, retweeted, source, text, truncated, user_created_at,  
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ) 
            VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)''', 
            (created_at, favorite_count, favorited, filter_level, lang, retweet_count, 
                         retweeted, source, text, truncated, user_created_at, 
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ))
        conn.commit()
        conn.close()
    
            
if __name__ == '__main__':
    
    hash_tag_list = ['mumbai']
    fetched_tweets_filename = "tweets.json"
    
    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
    
#     listener = StdOutListener()
#     auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
#     auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
    
#     stream = Stream(auth, listener)
    
#     stream.filter(track=['akshay kumar'])
# Out:
# {'created_at': 'Mon Feb 10 09:07:53 +0000 2020', 'id': 1226794906481389569, 'id_str': '1226794906481389569', 'text': 'Retail Jeweller India recommends M Suresh Co. Diamonds for IIJS Signature Show 2020 from Feb 13th to 16th, Mumbai… https://t.co/XSTNXYJiPV', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 575244731, 'id_str': '575244731', 'name': 'The RetailJeweller', 'screen_name': 'retailjwlrindia', 'location': 'Mumbai, Maharashtra', 'url': 'http://www.retailjewellerindia.com', 'description': 'The Retail Jeweller Magazine is the favourite business magazine of Jewellers in India and Middle East. Call us at +91-9920927129 or +91-22-61134999 !', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3343, 'friends_count': 1127, 'listed_count': 34, 'favourites_count': 963, 'statuses_count': 8375, 'created_at': 'Wed May 09 10:44:32 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'D6001D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'DB100D', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': 'D70707', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1213380816820006912/LDoRCMZ1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1213380816820006912/LDoRCMZ1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/575244731/1580103505', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Retail Jeweller India recommends M Suresh Co. Diamonds for IIJS Signature Show 2020 from Feb 13th to 16th, Mumbai\n\n#IIJS2020 #RetailJewellerIndia #MSureshDiamonds #Jewellery #Signature #Show #B2b #Show #Jewelry #Jewellery #b2bmarketing #retailjewellerworld @GJEPCIndia https://t.co/RcJUXRcQAg', 'display_text_range': [0, 268], 'entities': {'hashtags': [{'text': 'IIJS2020', 'indices': [115, 124]}, {'text': 'RetailJewellerIndia', 'indices': [125, 145]}, {'text': 'MSureshDiamonds', 'indices': [146, 162]}, {'text': 'Jewellery', 'indices': [163, 173]}, {'text': 'Signature', 'indices': [174, 184]}, {'text': 'Show', 'indices': [185, 190]}, {'text': 'B2b', 'indices': [191, 195]}, {'text': 'Show', 'indices': [196, 201]}, {'text': 'Jewelry', 'indices': [202, 210]}, {'text': 'Jewellery', 'indices': [211, 221]}, {'text': 'b2bmarketing', 'indices': [222, 235]}, {'text': 'retailjewellerworld', 'indices': [236, 256]}], 'urls': [], 'user_mentions': [{'screen_name': 'GJEPCIndia', 'name': 'GJEPC India', 'id': 862775707, 'id_str': '862775707', 'indices': [257, 268]}], 'symbols': [], 'media': [{'id': 1226794897333604352, 'id_str': '1226794897333604352', 'indices': [269, 292], 'media_url': 'http://pbs.twimg.com/media/EQZzdZPU0AA9tjS.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQZzdZPU0AA9tjS.jpg', 'url': 'https://t.co/RcJUXRcQAg', 'display_url': 'pic.twitter.com/RcJUXRcQAg', 'expanded_url': 'https://twitter.com/retailjwlrindia/status/1226794906481389569/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 749, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 799, 'h': 1280, 'resize': 'fit'}, 'small': {'w': 424, 'h': 680, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id' ...
# {'created_at': 'Mon Feb 10 09:07:55 +0000 2020', 'id': 1226794915155177472, 'id_str': '1226794915155177472', 'text': '❤❤❤❤❤ for #SidhartShukla \n#BiggBoss13', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 923448819496267776, 'id_str': '923448819496267776', 'name': 'Subhashree Jena', 'screen_name': 'jenasubhashree3', 'location': None, 'url': None, 'description': 'Because her Eyes have so much to tell about her zillion wishes and million questions...Read through the pictures. 😆', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count':
 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 46118671, 'id_str': '46118671', 'name': 'Sumit Kumar', 'screen_name': 'kumar_sumit', 'location': 'India', 'url': None, 'description': 'Factual NOT Neutral | Confused Rationalist | Meliorism infected | Procrastination crutch-ed |  Scribbler', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 5389, 'friends_count': 690, 'listed_count': 28, 'favourites_count': 8302, 'statuses_count': 15169, 'created_at': 'Wed Jun 10 14:05:54 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/2561326948/ofhnq56hbkooathpja1g_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2561326948/ofhnq56hbkooathpja1g_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/46118671/1488400439', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 10 06:00:00 +0000 2020', 'id': 1226747625010974721, 'id_str': '1226747625010974721', 'text': '#ICYMI Maharashtra government cancels allotment of CIDCO land to private developer. https://t.co/56zk1ajSQw', 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2348042388, 'id_str': '2348042388', 'name': 'The Hindu-Mumbai', 'screen_name': 'THMumbai', 'location': 'Mumbai, Maharashtra, India', 'url': 'http://www.thehindu.com/news/cities/mumbai/', 'description': 'The official Twitter account of The Hindu in Mumbai. Follow us for breaking news and updates about the city. Also on https://www.facebook.com/TheHinduMumbai', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 16982, 'friends_count': 940, 'listed_count': 104, 'favourites_count': 284, 'statuses_count': 32796, 'created_at': 'Mon Feb 17 06:50:15 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '5496C2', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDFFCC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1058354510282649601/ZT5NX6Iz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1058354510282649601/ZT5NX6Iz_normal.jpg', 'profile_banner_url': ' ...
# {'created_at': 'Mon Feb 10 09:08:02 +0000 2020', 'id': 1226794946386153477, 'id_str': '1226794946386153477', 'text': '#Vacancy #Fresher #Mumbai #ITsales\nHi,\nLeading CMMI Level 3 IT  company is hiring for  freshers for their  IT Sales… https://t.co/yef8IYkRfw', 'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 136659653, 'id_str': '136659653', 'name': 'Concepts India - HR Services', 'screen_name': 'ConceptsIndiBlr', 'location': 'Bangalore', 'url': 'http://www.conceptsindia.co.in', 'description': 'Leading HR Services Company with focus area in Recruitment & Training', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 116, 'friends_count': 100, 'listed_count': 0, 'favourites_count': 13, 'statuses_count': 816, 'created_at': 'Sat Apr 24 15:01:59 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': False, 'profile_link_color': '19CF86', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1082997664352849925/lcPlgILD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082997664352849925/lcPlgILD_normal.jpg', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '#Vacancy #Fresher #Mumbai #ITsales\nHi,\nLeading CMMI Level 3 IT  company is hiring for  freshers for their  IT Sales and Marketing team\n\nPosition name : Executive / Sr. Executive ( IT Sales &amp; Marketing)\nQualification    :  FRESHERS ( BE/BTECH or BCA or MBA…https://t.co/cBc1BaGpha', 'display_text_range': [0, 283], 'entities': {'hashtags': [{'text': 'Vacancy', 'indices': [0, 8]}, {'text': 'Fresher', 'indices': [9, 17]}, {'text': 'Mumbai', 'indices': [18, 25]}, {'text': 'ITsales', 'indices': [26, 34]}], 'urls': [{'url': 'https://t.co/cBc1BaGpha', 'expanded_url': 'https://lnkd.in/fQHrDTk', 'display_url': 'lnkd.in/fQHrDTk', 'indices': [260, 283]}], 'user_mentions': [], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'Vacancy', 'indices': [0, 8]}, {'text': 'Fresher', 'indices': [9, 17]}, {'text': 'Mumbai', 'indices': [18, 25]}, {'text': 'ITsales', 'indices': [26, 34]}], 'urls': [{'url': 'https://t.co/yef8IYkRfw', 'expanded_url': 'https://twitter.com/i/web/status/1226794946386153477', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1581325682623'}
# {'created_at': 'Mon Feb 10 09:08:03 +0000 2020', 'id': 1226794951242989568, 'id_str': '1226794951242989568', 'text': 'RT @SwarajyaMag: Mumbai Police Nabs Underworld Lynchpin Dawood Ibrahim’s Close Aide Tariq Parveen\n\nhttps://t.co/Jbwqa2BLeB', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 913371465608654848, 'id_str': '913371465608654848', 'name': 'Ashwani Chowdhry', 'screen_name': 'AshwaniChowdhry', 'location': 'Lucknow, India', 'url': None, 'description': 'A proud Indian. National interest supreme.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 385, 'friends_count': 859, 'listed_count': 3, 'favourites_count': 60977, 'statuses_count': 172883, 'created_at': 'Thu Sep 28 11:55:01 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/922737888252411904/HaRJnVMD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/922737888252411904/HaRJnVMD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/913371465608654848/1508832829', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 10 03:50:44 +0000 2020', 'id': 1226715095134158848, 'id_str': '1226715095134158848', 'text': 'Mumbai Police Nabs Underworld Lynchpin Dawood Ibrahim’s Close Aide Tariq Parveen\n\nhttps://t.co/Jbwqa2BLeB', 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2451476942, 'id_str': '2451476942', 'name': 'Swarajya', 'screen_name': 'SwarajyaMag', 'location': 'India', 'url': 'http://www.swarajyamag.com', 'description': 'A big tent for liberal right of centre discourse that reaches out, engages and caters to the new India', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 163423, 'friends_count': 675, 'listed_count': 697, 'favourites_count': 561, 'statuses_count': 89481, 'created_at': 'Fri Apr 18 14:51:38 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/510470436920893440/kd15XOx9_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/510470436920893440/kd15XOx9_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2451476942/1580443171', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None ...
# {'created_at': 'Mon Feb 10 09:08:04 +0000 2020', 'id': 1226794953772281857, 'id_str': '1226794953772281857', 'text': 'RT @misskaul: Hey NGOs in Delhi - interested in a #TwitterForGood workshop? 101 or even 301 which gives more info on hidden gems/product fe…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 55956191, 'id_str': '55956191', 'name': 'Abhishek Ranjan', 'screen_name': 'Deetee08', 'location': 'New Delhi, India', 'url': 'http://www.bharat2india.wordpress.com', 'description': 'Inspired by LIFE | Manipal | Barca | Floyd |\nEx-LAMP | Patna, Policy & Politics | JAI HIND.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 682, 'friends_count': 1316, 'listed_count': 13, 'favourites_count': 25873, 'statuses_count': 16651, 'created_at': 'Sat Jul 11 23:08:32 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_link_color': '0099B9', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1203765090853388288/LCNJssvy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1203765090853388288/LCNJssvy_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/55956191/1481644634', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 10 08:11:19 +0000 2020', 'id': 1226780672020238336, 'id_str': '1226780672020238336', 'text': 'Hey NGOs in Delhi - interested in a #TwitterForGood workshop? 101 or even 301 which gives more info on hidden gems/… https://t.co/CnMuPOW0bL', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18131765, 'id_str': '18131765', 'name': 'Mahima Kaul', 'screen_name': 'misskaul', 'location': None, 'url': None, 'description': 'Director, @policy @TwitterIndia & South Asia.... @mcgillu alum', 'translator_type': 'regular', 'protected': False, 'verified': False, 'followers_count': 26960, 'friends_count': 3059, 'listed_count': 185, 'favourites_count': 14583, 'statuses_count': 24140, 'created_at': 'Mon Dec 15 05:54:19 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '642D8B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_tile': True, 'profile_link_color': 'FF0000', 'profile_sidebar_border_color': '65B0DA', 'profile_sidebar_fill_color': '7AC3EE', 'profile_text_color': '3D1957', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1000029787228794880/Ekuz3kzo_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000029787228794880/Ekuz3kzo_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18131765/1548144655', 'default_profile': False, 'default_pro ...
# {'created_at': 'Mon Feb 10 09:08:04 +0000 2020', 'id': 1226794953809883136, 'id_str': '1226794953809883136', 'text': 'RT @DeepikaBhardwaj: A girl who blackmailed &amp; extorted 1.5Crores from a doctor after filing a #falserape case on him, where he spent 3 mont…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2723408084, 'id_str': '2723408084', 'name': 'శ్రీనివాస రావు', 'screen_name': 'Srinu258', 'location': 'Jaipur, India', 'url': None, 'description': 'తెలుగు మాట్లాడే భారతీయుణ్ణి, అభియాంత్రికుణ్ణి, విద్యార్థిని.\nTelugu speaking Indian, Engineer, Student.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 96, 'friends_count': 1192, 'listed_count': 2, 'favourites_count': 10067, 'statuses_count': 5169, 'created_at': 'Mon Aug 11 07:34:15 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1210033158420402176/If9QjrvD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1210033158420402176/If9QjrvD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2723408084/1472556303', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 10 08:10:14 +0000 2020', 'id': 1226780398400634880, 'id_str': '1226780398400634880', 'text': 'A girl who blackmailed &amp; extorted 1.5Crores from a doctor after filing a #falserape case on him, where he spent 3 m… https://t.co/oyaWfdy7XW', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 50243741, 'id_str': '50243741', 'name': 'Deepika Narayan Bhardwaj', 'screen_name': 'DeepikaBhardwaj', 'location': 'New Delhi, India', 'url': 'http://www.MartyrsofMarriage.com', 'description': 'Independent Journalist | Documentary Filmmaker DIRECTOR - #IndiasSons | #MartyrsofMarriage (NETFLIX: https://t.co/I5oMM52NVK?) Email: dnbhere@gmail.com', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 56585, 'friends_count': 2585, 'listed_count': 412, 'favourites_count': 6430, 'statuses_count': 94264, 'created_at': 'Wed Jun 24 07:29:17 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '020303', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif', 'profile_background_tile': True, 'profile_link_color': '6B2C65', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '080508', 'profile_text_color': '595259', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1217510050073169920/zhCDbPKV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/121751005007316992 ...
# {'created_at': 'Mon Feb 10 09:08:04 +0000 2020', 'id': 1226794955328212992, 'id_str': '1226794955328212992', 'text': '#Mumbai: New #Charni Road #ROB may be opened by July https://t.co/l1ErapUxbq', 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1226781692544745474, 'id_str': '1226781692544745474', 'name': 'Ashok Panvalkar', 'screen_name': 'ashokpanvalkar', 'location': None, 'url': None, 'description': "Personal account as a Journalist. RT's are not endorsements. Opinion is Personal.", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 0, 'friends_count': 0, 'listed_count': 0, 'favourites_count': 0, 'statuses_count': 1, 'created_at': 'Mon Feb 10 08:15:34 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1226784076842950656/IPb8NQfQ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226784076842950656/IPb8NQfQ_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'Mumbai', 'indices': [0, 7]}, {'text': 'Charni', 'indices': [13, 20]}, {'text': 'ROB', 'indices': [26, 30]}], 'urls': [{'url': 'https://t.co/l1ErapUxbq', 'expanded_url': 'http://toi.in/ElvHhb79/a24gk', 'display_url': 'toi.in/ElvHhb79/a24gk', 'indices': [53, 76]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1581325684755'}
# {'created_at': 'Mon Feb 10 09:08:05 +0000 2020', 'id': 1226794958780129282, 'id_str': '1226794958780129282', 'text': 'RT @MirrorNow: #Fake notes worth ₹24 lakh seized after a fake note racket was busted in #Mumbai.\n\n@avniraja takes you through the security…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 577160876, 'id_str': '577160876', 'name': 'Chander Rana - Jai Hind🇮🇳', 'screen_name': 'chander_pratap', 'location': 'India', 'url': None, 'description': 'Human, Har Har Mahadev', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 221, 'friends_count': 568, 'listed_count': 1, 'favourites_count': 5230, 'statuses_count': 4756, 'created_at': 'Fri May 11 14:03:45 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1172565955777482752/fuuuclAF_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1172565955777482752/fuuuclAF_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 10 05:13:28 +0000 2020', 'id': 1226735913809543170, 'id_str': '1226735913809543170', 'text': '#Fake notes worth ₹24 lakh seized after a fake note racket was busted in #Mumbai.\n\n@avniraja takes you through the… https://t.co/K0L436XJOH', 'display_text_range': [0, 140], 'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3638215945, 'id_str': '3638215945', 'name': 'Mirror Now', 'screen_name': 'MirrorNow', 'location': 'India', 'url': 'http://www.mirrornownews.com', 'description': "Mirror Now's Mission: Demand accountability and relentlessly drive improvement by addressing everyday issues.", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 75510, 'friends_count': 27, 'listed_count': 327, 'favourites_count': 1, 'statuses_count': 86059, 'created_at': 'Mon Sep 21 13:31:19 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/844708508989841408/HLuil94O_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/844708508989841408/HLuil94O_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3638215945/1580731209', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notification ...
# ...
# {'created_at': 'Mon Feb 10 09:10:15 +0000 2020', 'id': 1226795501917335553, 'id_str': '1226795501917335553', 'text': 'RT @TV9Bharatvarsh: मुंबई रैली में #RajThackeray बोले- #CAA का क्यों विरोध कर रहे मुसलमान, किसे दिखा रहे हैं ताकत? #MNSMahaMorcha\n\nhttps://…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1030430959, 'id_str': '1030430959', 'name': 'दिनेश आर्य', 'screen_name': 'DineshArya1667', 'location': 'mumbai', 'url': None, 'description': 'स्वयंसेवक', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 31, 'friends_count': 160, 'listed_count': 0, 'favourites_count': 2282, 'statuses_count': 2084, 'created_at': 'Sun Dec 23 11:50:14 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1214836583255248896/L5sAvlv4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214836583255248896/L5sAvlv4_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1030430959/1578474586', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 10 00:30:00 +0000 2020', 'id': 1226664577712046081, 'id_str': '1226664577712046081', 'text': 'मुंबई रैली में #RajThackeray बोले- #CAA का क्यों विरोध कर रहे मुसलमान, किसे दिखा रहे हैं ताकत? #MNSMahaMorcha\n\nhttps://t.co/qsMxjdElKv', 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1039759933728645120, 'id_str': '1039759933728645120', 'name': 'TV9 भारतवर्ष', 'screen_name': 'TV9Bharatvarsh', 'location': 'Noida, India', 'url': 'http://www.tv9bharatvarsh.com', 'description': 'Official handle of National Hindi News Channel TV9 भारतवर्ष. After @TV9Telugu @tv9kannada @tv9gujarati @TV9Marathi We are here to say हिंदी हैं हम !!', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 73892, 'friends_count': 78, 'listed_count': 64, 'favourites_count': 0, 'statuses_count': 51065, 'created_at': 'Wed Sep 12 06:17:40 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1096347470911569920/bIhMH_TA_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096347470911569920/bIhMH_TA_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1039759933728645120/1580739901', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent':  ...
# {'created_at': 'Mon Feb 10 09:10:15 +0000 2020', 'id': 1226795504098594816, 'id_str': '1226795504098594816', 'text': 'RT @abhijitmajumder: Had got an email from a Leftist friend right after 26/11 claiming Mumbai attacks were handiwork of India/Hindus. Can’t…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 113327669, 'id_str': '113327669', 'name': 'Atul', 'screen_name': 'atulkelkar', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 227, 'friends_count': 292, 'listed_count': 18, 'favourites_count': 51063, 'statuses_count': 22314, 'created_at': 'Thu Feb 11 12:03:29 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/113327669/1476341215', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 09 19:44:37 +0000 2020', 'id': 1226592760100032512, 'id_str': '1226592760100032512', 'text': 'Had got an email from a Leftist friend right after 26/11 claiming Mumbai attacks were handiwork of India/Hindus. Ca… https://t.co/5FgoRkMhGD', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 56039856, 'id_str': '56039856', 'name': 'Abhijit Majumder', 'screen_name': 'abhijitmajumder', 'location': 'New Delhi, India', 'url': 'https://twitter.com/abhijitmajumder', 'description': 'Journalist. Views are personal, retweets not necessarily endorsements', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 538083, 'friends_count': 517, 'listed_count': 1112, 'favourites_count': 906, 'statuses_count': 54006, 'created_at': 'Sun Jul 12 07:04:15 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'B2DFDA', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif', 'profile_background_tile': False, 'profile_link_color': '93A644', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1224583579897716736/zur3-zf2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1224583579897716736/zur3-zf2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/56039856/1527593301', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications' ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a4e9b6fa4471> in <module>()
#      91
#      92     twitter_streamer = TwitterStreamer()
# ---> 93     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#      94
#      95 #     listener = StdOutListener()
#
# <ipython-input-1-a4e9b6fa4471> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      18         stream = Stream(auth, listener)
#      19
# ---> 20         stream.filter(track=['Mumbai'])
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:
