# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import json
import dataset
import credentials
import sqlite3

# db = dataset.connect("sqlite:///tweet2.db")

class TwitterStreamer():
    
    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
        auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
        
        stream = Stream(auth, listener)
        
        stream.filter(track=['Mumbai'])
        
 
class StdOutListener(StreamListener):
    
    def on_status(self, status):
        print(status.text)

    def on_error(self, status):
        print(status)

    def on_data(self, data):
        all_data             = json.loads(data)
        created_at           = all_data['created_at']
        favorite_count       = all_data['favorite_count']
        favorited            = all_data['favorited']
        filter_level         = all_data['filter_level']
        lang                 = all_data['lang']
        retweet_count        = all_data['retweet_count']
        retweeted            = all_data['retweeted']
        source               = all_data['source']
        text                 = all_data['text']
        truncated            = all_data['truncated']
        user_created_at      = all_data['user']['created_at']
        user_followers_count = all_data['user']['followers_count']
        user_location        = all_data['user']['location']
        user_lang            = all_data['user']['lang']
        user_name            = all_data['user']['name']
        user_screen_name     = all_data['user']['screen_name']
        user_time_zone       = all_data['user']['time_zone']
        user_utc_offset      = all_data['user']['utc_offset']
        user_friends_count   = all_data['user']['friends_count']
        geo_enabled          = all_data['user']['geo_enabled']  
        coordinates          = all_data['coordinates']
        geo                  = all_data['geo']
        place                = all_data['place']
        if place is not None:
            place_name       = all_data['place']['name']
        else:
            place_name       = all_data['place']
        
        print(all_data)
    
        
        conn = sqlite3.connect('tweet2.db')
        c = conn.cursor()
        
        #c.execute("""CREATE TABLE tweets
        #(created_at, favorite_count, favorited, filter_level, lang, 
         #                retweet_count, retweeted, source, text, truncated, user_created_at,  
        #                user_followers_count, user_location, user_lang, user_name, 
        #                 user_screen_name, user_time_zone, user_friends_count,geo_enabled,geo,place_name)""")
                         
        c.execute('''INSERT INTO tweets 
        (created_at, favorite_count, favorited, filter_level, lang, 
                         retweet_count, retweeted, source, text, truncated, user_created_at,  
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ) 
            VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)''', 
            (created_at, favorite_count, favorited, filter_level, lang, retweet_count, 
                         retweeted, source, text, truncated, user_created_at, 
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ))
        conn.commit()
        conn.close()
    
            
if __name__ == '__main__':
    
    hash_tag_list = ['mumbai']
    fetched_tweets_filename = "tweets.json"
    
    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
    
#     listener = StdOutListener()
#     auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
#     auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
    
#     stream = Stream(auth, listener)
    
#     stream.filter(track=['akshay kumar'])
# Out:
# {'created_at': 'Sun Feb 09 17:29:41 +0000 2020', 'id': 1226558802926825472, 'id_str': '1226558802926825472', 'text': "RT @MirchandaniYana: Pro CAA support rally in South Mumbai\nBy guess who? #MNS #RajThackeray 's party\nWe need to show more support like this…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 275941910, 'id_str': '275941910', 'name': 'MPS', 'screen_name': 'likz84', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 48, 'friends_count': 15, 'listed_count': 0, 'favourites_count': 10817, 'statuses_count': 10955, 'created_at': 'Sat Apr 02 09:36:11 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_link_color': '009999', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1165462222488817665/YsTbeHcq_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1165462222488817665/YsTbeHcq_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/275941910/1579719439', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 09 09:08:11 +0000 2020', 'id': 1226432596214611968, 'id_str': '1226432596214611968', 'text': "Pro CAA support rally in South Mumbai\nBy guess who? #MNS #RajThackeray 's party\nWe need to show more support like t… https://t.co/GsZKwxbdQw", 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1100302269570936832, 'id_str': '1100302269570936832', 'name': 'Yana Mirchandani   يانا مِرچندانى', 'screen_name': 'MirchandaniYana', 'location': 'Sonamarg, Mumbai', 'url': None, 'description': 'Kashur, PROUD INDIAN FIRST! 🇮🇳 Activist, Political Analyst, Krav Maga Aspirant', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 30453, 'friends_count': 105, 'listed_count': 42, 'favourites_count': 2990, 'statuses_count': 4497, 'created_at': 'Tue Feb 26 07:51:18 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1169884803367235585/QE6eDpa9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1169884803367235585/QE6eDpa9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100302269570936832/1564846108', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates' ...
# {'created_at': 'Sun Feb 09 17:29:43 +0000 2020', 'id': 1226558809214267392, 'id_str': '1226558809214267392', 'text': 'RT @iMac_too: In Dilli, Muslims "allowed" a Hindu funeral procession through "their" area\n\nIn Mumbai, police diverted a Hindu rally avoidin…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 54845755, 'id_str': '54845755', 'name': 'Sapna', 'screen_name': 'dream_np', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1357, 'friends_count': 438, 'listed_count': 16, 'favourites_count': 6992, 'statuses_count': 21988, 'created_at': 'Wed Jul 08 09:12:26 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'CC5C00', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1131787296016150529/27GECQ0u_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1131787296016150529/27GECQ0u_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/54845755/1423313393', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 09 09:42:45 +0000 2020', 'id': 1226441292839706624, 'id_str': '1226441292839706624', 'text': 'In Dilli, Muslims "allowed" a Hindu funeral procession through "their" area\n\nIn Mumbai, police diverted a Hindu ral… https://t.co/Mkb1IGMSVw', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 120649992, 'id_str': '120649992', 'name': 'iMac_too', 'screen_name': 'iMac_too', 'location': 'Mumbai', 'url': None, 'description': "'That's not the point.'", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 46339, 'friends_count': 155, 'listed_count': 291, 'favourites_count': 2739, 'statuses_count': 89413, 'created_at': 'Sun Mar 07 03:39:16 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3585208466/59e736185b36b080430cb1c63aecd2bc_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3585208466/59e736185b36b080430cb1c63aecd2bc_normal.jpeg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'In Dilli, Musl ...
# {'created_at': 'Sun Feb 09 17:29:43 +0000 2020', 'id': 1226558811822903298, 'id_str': '1226558811822903298', 'text': 'RT @cskkanu: Big salute to the team.\n\n#MenWillBeMen \n\n#feminists are not asking equality here.\n#FeminismIsCancer', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 833342797864243200, 'id_str': '833342797864243200', 'name': 'solovijay', 'screen_name': 'solovijay17', 'location': None, 'url': None, 'description': 'A Veteran, MRA, Fighter, Helper', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 241, 'friends_count': 164, 'listed_count': 0, 'favourites_count': 3234, 'statuses_count': 2503, 'created_at': 'Sun Feb 19 15:49:40 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/869174153324220417/tYpPNP8U_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/869174153324220417/tYpPNP8U_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Feb 08 19:13:57 +0000 2020', 'id': 1226222652131401728, 'id_str': '1226222652131401728', 'text': 'Big salute to the team.\n\n#MenWillBeMen \n\n#feminists are not asking equality here.\n#FeminismIsCancer', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 64355384, 'id_str': '64355384', 'name': 'Chetan', 'screen_name': 'cskkanu', 'location': 'Save Family System', 'url': None, 'description': "Men's rights activist \n#FakeCases winner,  \nTarget-To Fight and Scrap Biased Laws Against Men. To Stop Male Suicides.\nRT means not a consented views.", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3589, 'friends_count': 4794, 'listed_count': 68, 'favourites_count': 20204, 'statuses_count': 81379, 'created_at': 'Mon Aug 10 07:31:19 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1226417526088712192/NosiYOXk_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226417526088712192/NosiYOXk_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/64355384/1401043878', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1226025319364059137, 'quoted_status_id_str': '12 ...
# {'created_at': 'Sun Feb 09 17:29:45 +0000 2020', 'id': 1226558817971761152, 'id_str': '1226558817971761152', 'text': "#RajThackeray #mnsmorcha appreciate your effort towrds this ...let's unite again against all the outsider ....we al… https://t.co/KxWQ7VIjj5", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 230673504, 'id_str': '230673504', 'name': 'Sanjeev', 'screen_name': 'sanjeevkp27', 'location': 'Pune, India', 'url': None, 'description': 'Strong follower of Indian culture and values', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 20, 'friends_count': 130, 'listed_count': 0, 'favourites_count': 13, 'statuses_count': 25, 'created_at': 'Sun Dec 26 08:58:20 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1225745851089162243/qFkGgKea_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225745851089162243/qFkGgKea_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/230673504/1581075713', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1226508328496291841, 'quoted_status_id_str': '1226508328496291841', 'quoted_status': {'created_at': 'Sun Feb 09 14:09:07 +0000 2020', 'id': 1226508328496291841, 'id_str': '1226508328496291841', 'text': 'A special mention of the exceptional maintenance of law and order during the Mahamorcha by the Mumbai Police.The Ma… https://t.co/49RAmdW2cI', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864794008496742400, 'id_str': '864794008496742400', 'name': 'Raj Thackeray', 'screen_name': 'RajThackeray', 'location': None, 'url': 'http://facebook.com/RajThackeray', 'description': 'Official Twitter Handle Of Raj Thackeray', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 337006, 'friends_count': 1, 'listed_count': 94, 'favourites_count': 2, 'statuses_count': 338, 'created_at': 'Wed May 17 10:45:33 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/989399987405570048/7jvx8lPl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989399987405570048/7jvx8lPl_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864794008496742400/1525099228', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notif ...
# {'created_at': 'Sun Feb 09 17:29:46 +0000 2020', 'id': 1226558823298527232, 'id_str': '1226558823298527232', 'text': "RT @MirchandaniYana: Pro CAA support rally in South Mumbai\nBy guess who? #MNS #RajThackeray 's party\nWe need to show more support like this…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 100179087, 'id_str': '100179087', 'name': 'Sharad', 'screen_name': 'callsharad', 'location': 'Earth', 'url': None, 'description': 'कर्मण्येवाधिकारस्ते मा फलेषु कदाचन।\nमा कर्मफलहेतुर्भूर्मा ते सङ्गोऽस्त्वकर्मणि॥', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 923, 'friends_count': 865, 'listed_count': 1, 'favourites_count': 15000, 'statuses_count': 16464, 'created_at': 'Tue Dec 29 08:55:26 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1219921826446368768/Z4z18ikL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1219921826446368768/Z4z18ikL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/100179087/1530730842', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 09 09:08:11 +0000 2020', 'id': 1226432596214611968, 'id_str': '1226432596214611968', 'text': "Pro CAA support rally in South Mumbai\nBy guess who? #MNS #RajThackeray 's party\nWe need to show more support like t… https://t.co/GsZKwxbdQw", 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1100302269570936832, 'id_str': '1100302269570936832', 'name': 'Yana Mirchandani   يانا مِرچندانى', 'screen_name': 'MirchandaniYana', 'location': 'Sonamarg, Mumbai', 'url': None, 'description': 'Kashur, PROUD INDIAN FIRST! 🇮🇳 Activist, Political Analyst, Krav Maga Aspirant', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 30453, 'friends_count': 105, 'listed_count': 42, 'favourites_count': 2990, 'statuses_count': 4497, 'created_at': 'Tue Feb 26 07:51:18 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1169884803367235585/QE6eDpa9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1169884803367235585/QE6eDpa9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100302269570936832/1564846108', 'default_profile': True, 'default_profile_image': False, 'following' ...
# {'created_at': 'Sun Feb 09 17:29:47 +0000 2020', 'id': 1226558827174211584, 'id_str': '1226558827174211584', 'text': 'RT @ashramgoregaon: On #MaghiPurnima Satsang by Shri Vasudevanand Ji~\n\n🗓: 9 Feb\n⏰: 5Pm~\n📍: #Goregaon #Ashram\n\nWe #CountdownToParentsWorship…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4333018633, 'id_str': '4333018633', 'name': 'Khyati Makode', 'screen_name': 'KhyatiMakode', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1191, 'friends_count': 701, 'listed_count': 2, 'favourites_count': 21150, 'statuses_count': 28949, 'created_at': 'Mon Nov 23 10:28:35 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/715162023395516416/ySTrceL4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/715162023395516416/ySTrceL4_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 09 04:44:18 +0000 2020', 'id': 1226366185597333504, 'id_str': '1226366185597333504', 'text': 'On #MaghiPurnima Satsang by Shri Vasudevanand Ji~\n\n🗓: 9 Feb\n⏰: 5Pm~\n📍: #Goregaon #Ashram\n\nWe… https://t.co/sRnQA8bnsQ', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 780862693, 'id_str': '780862693', 'name': 'AshramGoreGaon', 'screen_name': 'ashramgoregaon', 'location': 'Mumbai', 'url': 'http://www.ashram.org', 'description': 'Sant Shri Asharam Ji Bapu Ashram, Goregaon, Mumbai', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 13157, 'friends_count': 494, 'listed_count': 39, 'favourites_count': 4810, 'statuses_count': 23266, 'created_at': 'Sat Aug 25 18:45:00 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '56C1AF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_link_color': '56C1AF', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/910760165191962624/BiKd1FkX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/910760165191962624/BiKd1FkX_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/780862693/1580662943', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': Fals ...
# {'created_at': 'Sun Feb 09 17:29:49 +0000 2020', 'id': 1226558837533990912, 'id_str': '1226558837533990912', 'text': 'RT @ashramgoregaon: On #MaghiPurnima Satsang by Shri Vasudevanand Ji~\n\n🗓: 9 Feb\n⏰: 5Pm~\n📍: #Goregaon #Ashram\n\nWe #CountdownToParentsWorship…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id':
 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/949346444598763525/JLCdAUiP_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/949346444598763525/JLCdAUiP_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/949344373090680832/1531537051', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 09 14:09:07 +0000 2020', 'id': 1226508328496291841, 'id_str': '1226508328496291841', 'text': 'A special mention of the exceptional maintenance of law and order during the Mahamorcha by the Mumbai Police.The Ma… https://t.co/49RAmdW2cI', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864794008496742400, 'id_str': '864794008496742400', 'name': 'Raj Thackeray', 'screen_name': 'RajThackeray', 'location': None, 'url': 'http://facebook.com/RajThackeray', 'description': 'Official Twitter Handle Of Raj Thackeray', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 337011, 'friends_count': 1, 'listed_count': 94, 'favourites_count': 2, 'statuses_count': 338, 'created_at': 'Wed May 17 10:45:33 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/989399987405570048/7jvx8lPl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989399987405570048/7jvx8lPl_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864794008496742400/1525099228', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'A s ...
# {'created_at': 'Sun Feb 09 17:29:54 +0000 2020', 'id': 1226558858925084672, 'id_str': '1226558858925084672', 'text': 'RT @tajmahalfoxtrot: .@UberINSupport It would be useful to know what action has been taken against the taxi driver who drove his customer t…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 979062662695923715, 'id_str': '979062662695923715', 'name': 'Hilary Newnes', 'screen_name': 'HilaryNewnes', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 170, 'friends_count': 237, 'listed_count': 0, 'favourites_count': 66726, 'statuses_count': 69086, 'created_at': 'Wed Mar 28 18:28:23 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Feb 08 04:31:41 +0000 2020', 'id': 1226000623193051136, 'id_str': '1226000623193051136', 'text': '.@UberINSupport It would be useful to know what action has been taken against the taxi driver who drove his custome… https://t.co/f88qodw7AL', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 303059786, 'id_str': '303059786', 'name': 'naresh fernandes', 'screen_name': 'tajmahalfoxtrot', 'location': 'mumbai', 'url': 'http://www.scroll.in', 'description': 'Editor, Scroll.in. Tweets about journalism and all that jazz.', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 52655, 'friends_count': 1919, 'listed_count': 450, 'favourites_count': 7042, 'statuses_count': 44519, 'created_at': 'Sun May 22 07:20:20 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1072512769008766977/DpKTDbm5_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1072512769008766977/DpKTDbm5_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/303059786/1576477749', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '.@UberINSupport It would be useful to know wh ...
# ...
# {'created_at': 'Sun Feb 09 17:29:58 +0000 2020', 'id': 1226558873386934272, 'id_str': '1226558873386934272', 'text': 'RT @mehtapriyanka07: Heard kitten mews at 3am and found this baby, all alone. Maybe a few weeks old. Mother is not around. Anyone from #Mum…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 354808045, 'id_str': '354808045', 'name': 'suneeta mehan', 'screen_name': 'suneetamehan', 'location': "'pink' city", 'url': None, 'description': 'https://aakashganga.home.blog/', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2000, 'friends_count': 1223, 'listed_count': 7, 'favourites_count': 205460, 'statuses_count': 69443, 'created_at': 'Sun Aug 14 10:02:53 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/884096890593091585/O5mzhI2U_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/884096890593091585/O5mzhI2U_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/354808045/1573219639', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Feb 08 02:44:24 +0000 2020', 'id': 1225973624688922624, 'id_str': '1225973624688922624', 'text': 'Heard kitten mews at 3am and found this baby, all alone. Maybe a few weeks old. Mother is not around. Anyone from… https://t.co/LcFcJWE6HE', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3240487412, 'id_str': '3240487412', 'name': 'Priyanka', 'screen_name': 'mehtapriyanka07', 'location': 'Mumbai, India', 'url': None, 'description': 'Cats and Dogs over Humans |\nDesigner. Bi.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 36, 'friends_count': 313, 'listed_count': 0, 'favourites_count': 4114, 'statuses_count': 158, 'created_at': 'Tue Jun 09 05:35:18 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1220777266625445888/A1Ww-XZt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220777266625445888/A1Ww-XZt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3240487412/1572113812', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, ' ...
# {'created_at': 'Sun Feb 09 17:29:58 +0000 2020', 'id': 1226558873617567749, 'id_str': '1226558873617567749', 'text': "RT @MirchandaniYana: Pro CAA support rally in South Mumbai\nBy guess who? #MNS #RajThackeray 's party\nWe need to show more support like this…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 87393985, 'id_str': '87393985', 'name': 'Ancient Soul', 'screen_name': 'nirav1612', 'location': None, 'url': None, 'description': 'Ancient soul in modern world....Belongs to Stardust....Believe in Equality....Spiritual....', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 331, 'friends_count': 2707, 'listed_count': 4, 'favourites_count': 120420, 'statuses_count': 33945, 'created_at': 'Wed Nov 04 08:32:27 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1205373952316436480/3qK2Vq8o_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1205373952316436480/3qK2Vq8o_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/87393985/1442312493', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 09 09:08:11 +0000 2020', 'id': 1226432596214611968, 'id_str': '1226432596214611968', 'text': "Pro CAA support rally in South Mumbai\nBy guess who? #MNS #RajThackeray 's party\nWe need to show more support like t… https://t.co/GsZKwxbdQw", 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1100302269570936832, 'id_str': '1100302269570936832', 'name': 'Yana Mirchandani   يانا مِرچندانى', 'screen_name': 'MirchandaniYana', 'location': 'Sonamarg, Mumbai', 'url': None, 'description': 'Kashur, PROUD INDIAN FIRST! 🇮🇳 Activist, Political Analyst, Krav Maga Aspirant', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 30453, 'friends_count': 105, 'listed_count': 42, 'favourites_count': 2990, 'statuses_count': 4497, 'created_at': 'Tue Feb 26 07:51:18 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1169884803367235585/QE6eDpa9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1169884803367235585/QE6eDpa9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100302269570936832/1564846108', 'default_profile': True, 'default_profile_image': False ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a4e9b6fa4471> in <module>()
#      91
#      92     twitter_streamer = TwitterStreamer()
# ---> 93     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#      94
#      95 #     listener = StdOutListener()
#
# <ipython-input-5-a4e9b6fa4471> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      18         stream = Stream(auth, listener)
#      19
# ---> 20         stream.filter(track=['Mumbai'])
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:
