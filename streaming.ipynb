# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import json
import dataset
import credentials
import sqlite3

# db = dataset.connect("sqlite:///tweet2.db")

class TwitterStreamer():
    
    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
        auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
        
        stream = Stream(auth, listener, tweet_mode='extended')
        
        stream.filter(track=['Mumbai'])
        
 
class StdOutListener(StreamListener):
    
    def on_status(self, status):
        print(status.text)
        #print('full_text:', status.extended_tweet['full_text'])
    def on_error(self, status):
        print(status)

    def on_data(self, data):
        all_data             = json.loads(data)
        created_at           = all_data['created_at']
        favorite_count       = all_data['favorite_count']
        favorited            = all_data['favorited']
        filter_level         = all_data['filter_level']
        lang                 = all_data['lang']
        retweet_count        = all_data['retweet_count']
        retweeted            = all_data['retweeted']
        source               = all_data['source']
        text                 = all_data['text']
        #full_text            = all_data['full_text']
        truncated            = all_data['truncated']
        user_created_at      = all_data['user']['created_at']
        user_followers_count = all_data['user']['followers_count']
        user_location        = all_data['user']['location']
        user_lang            = all_data['user']['lang']
        user_name            = all_data['user']['name']
        user_screen_name     = all_data['user']['screen_name']
        user_time_zone       = all_data['user']['time_zone']
        user_utc_offset      = all_data['user']['utc_offset']
        user_friends_count   = all_data['user']['friends_count']
        geo_enabled          = all_data['user']['geo_enabled']  
        coordinates          = all_data['coordinates']
        geo                  = all_data['geo']
        place                = all_data['place']
        if place is not None:
            place_name       = all_data['place']['name']
        else:
            place_name       = all_data['place']
        
        print(all_data)
    
        
        conn = sqlite3.connect('tweet2.db')
        c = conn.cursor()
        
        #c.execute("""CREATE TABLE tweets
        #(created_at, favorite_count, favorited, filter_level, lang, 
         #                retweet_count, retweeted, source, text, truncated, user_created_at,  
        #                user_followers_count, user_location, user_lang, user_name, 
        #                 user_screen_name, user_time_zone, user_friends_count,geo_enabled,geo,place_name)""")
                         
        c.execute('''INSERT INTO tweets 
        (created_at, favorite_count, favorited, filter_level, lang, 
                         retweet_count, retweeted, source, text, truncated, user_created_at,  
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ) 
            VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)''', 
            (created_at, favorite_count, favorited, filter_level, lang, retweet_count, 
                         retweeted, source, text, truncated, user_created_at, 
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ))
        conn.commit()
        conn.close()
    
            
if __name__ == '__main__':
    
    hash_tag_list = ['mumbai']
    fetched_tweets_filename = "tweets.json"
    
    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
    
#     listener = StdOutListener()
#     auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
#     auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
    
#     stream = Stream(auth, listener)
    
#     stream.filter(track=['akshay kumar'])
# Out:
# {'created_at': 'Sat Mar 21 10:04:13 +0000 2020', 'id': 1241304598712733697, 'id_str': '1241304598712733697', 'text': 'RT @pashyantii: And then people are asking why the #JantaCurfewMarch22 is needed?', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 548902952, 'id_str': '548902952', 'name': 'Stay Home', 'screen_name': 'isuyashsingh', 'location': 'Lucknow, India', 'url': None, 'description': 'एक ही फ़न तो हमने सीखा है \nजिस से मिलिए उसे ख़फ़ा कीजिये ।', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 92, 'friends_count': 534, 'listed_count': 0, 'favourites_count': 4357, 'statuses_count': 1684, 'created_at': 'Mon Apr 09 03:18:23 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1214490714429644801/iD_Ao764_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214490714429644801/iD_Ao764_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/548902952/1583092442', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 21 10:02:56 +0000 2020', 'id': 1241304274543374336, 'id_str': '1241304274543374336', 'text': 'And then people are asking why the #JantaCurfewMarch22 is needed?', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 126722450, 'id_str': '126722450', 'name': 'पश्यन्ती शुक्ला #ISupportJantaCurfew', 'screen_name': 'pashyantii', 'location': 'Delhi, भारत (India)', 'url': None, 'description': 'नमस्ते सदा वत्सले मातृभूमे 🇮🇳Ex-Journo | Comms Professional| Mother!Gayatri Parivar! Heart in Poetry,Brain in Politics l Followed by PM @narendramodi', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 10630, 'friends_count': 1090, 'listed_count': 49, 'favourites_count': 9405, 'statuses_count': 31764, 'created_at': 'Fri Mar 26 19:52:43 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FCEBB6', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_tile': True, 'profile_link_color': 'FF691F', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '78C0A8', 'profile_text_color': 'CE7834', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1239091334541008899/DYOevUxR_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1239091334541008899/DYOevUxR_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/126722450/1443779839', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notification ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-69ea16a6a5f9> in <module>
#      93
#      94     twitter_streamer = TwitterStreamer()
# ---> 95     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#      96
#      97 #     listener = StdOutListener()
#
# <ipython-input-10-69ea16a6a5f9> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      18         stream = Stream(auth, listener, tweet_mode='extended')
#      19
# ---> 20         stream.filter(track=['Mumbai'])
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# ~\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# <ipython-input-10-69ea16a6a5f9> in on_data(self, data)
#      61
#      62         print(all_data)
# ---> 63         print(full_text)
#      64
#      65
#
# NameError: name 'full_text' is not defined

# %%
import tweepy
auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)
public_tweets = api.search(q="coronavirus", tweet_mode='extended')
# foreach through all tweets pulled
for tweet in public_tweets:
   # printing the text stored inside the tweet object
   print(tweet.full_text)
# Out:
# RT @ChiefNGB: I hear unfounded rumors about #NationalGuard troops supporting a nationwide quarantine. Let me be clear: There has been no su…
# RT @haveigotnews: Live scenes as coronavirus forces retired doctors back into work: https://t.co/MK6uTvSc5M
# RT @Mippcivzla: #EnVivo 🔴 | Pdte. @NicolasMaduro: Es una basura lo que escribió el Washington Post (@washingtonpost) hoy contra Venezuela,…
# RT @brendasafra: vocês sabiam que no complexo do alemão tá sem água há 15 dias? e que a melhor forma de prevenção do coronavirus é lavar as…
# RT @HeyTammyBruce: Very important analysis here, valuable perspective as we are coming to realize our current reaction condemns our entire…
# RT @sebharias: Leo que Rusia está probando 6 vacunas contra el coronavirus y es un hermoso alivio. Pero NECESITO que la vacuna sea Chino-Cu…
# RT @MirrorCeleb: EXCLUSIVE: Coronavirus sees @westlifemusic cancel No1 DVD celebrations out of respect for fans https://t.co/9KLCtR2KQA htt…
# RT @ciiinners: kris leaking the entire phone call video between kanye and taylor so people can go back to talking about the kardashians rat…
# RT @sir_virgi69: Abeg for those of us who will survive this Coronavirus Pandemic, The first 5 houses in Trasacco Phase 1 are mine.... I don…
# RT @dicksgraysn: i’m living for sophie turner dragging evangeline lilly and vanessa hudgens after they said the coronavirus quarantine is o…
# RT @monstrousfemin1: บทความนิวยอร์กไทมส์ บอกว่าประเทศที่ตรวจโควิด-19 ให้ประชาชนไม่ได้ ไม่ใช่เรื่องของวิทยาศาสตร์ แต่เป็นเรื่องการเมืองและกา…
# RT @davidfrawleyved: On top of disrupting the rules for public behavior, Shaheen Bagh is putting everyone at risk by not following the rule…
# RT @elamin88: The epidemiologist who helped eradicate smallpox says Trump’s early handling of COVID-19 is “is the most irresponsible act of…
# Coronavirus: la Ligue 1 finalement à huis clos jusqu'au 15 avril - https://t.co/1XzlKEgCFf https://t.co/3oA5bUvLES
# RT @josephjett: Your Money - Separation anxiety: Divorce, money and coronavirus https://t.co/sIgPIKkSYM https://t.co/5RxUsNbCpE
