# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import json
import dataset
import credentials
import sqlite3

# db = dataset.connect("sqlite:///tweet2.db")

class TwitterStreamer():
    
    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
        auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
        
        stream = Stream(auth, listener)
        
        stream.filter(track=['Mumbai'])
        
 
class StdOutListener(StreamListener):
    
    def on_status(self, status):
        print(status.text)

    def on_error(self, status):
        print(status)

    def on_data(self, data):
        all_data             = json.loads(data)
        created_at           = all_data['created_at']
        favorite_count       = all_data['favorite_count']
        favorited            = all_data['favorited']
        filter_level         = all_data['filter_level']
        lang                 = all_data['lang']
        retweet_count        = all_data['retweet_count']
        retweeted            = all_data['retweeted']
        source               = all_data['source']
        text                 = all_data['text']
        truncated            = all_data['truncated']
        user_created_at      = all_data['user']['created_at']
        user_followers_count = all_data['user']['followers_count']
        user_location        = all_data['user']['location']
        user_lang            = all_data['user']['lang']
        user_name            = all_data['user']['name']
        user_screen_name     = all_data['user']['screen_name']
        user_time_zone       = all_data['user']['time_zone']
        user_utc_offset      = all_data['user']['utc_offset']
        user_friends_count   = all_data['user']['friends_count']
        geo_enabled          = all_data['user']['geo_enabled']  
        coordinates          = all_data['coordinates']
        geo                  = all_data['geo']
        place                = all_data['place']
        if place is not None:
            place_name       = all_data['place']['name']
        else:
            place_name       = all_data['place']
        
        print(all_data)
    
        
        conn = sqlite3.connect('tweet2.db')
        c = conn.cursor()
        
        #c.execute("""CREATE TABLE tweets
        #(created_at, favorite_count, favorited, filter_level, lang, 
         #                retweet_count, retweeted, source, text, truncated, user_created_at,  
        #                user_followers_count, user_location, user_lang, user_name, 
        #                 user_screen_name, user_time_zone, user_friends_count,geo_enabled,geo,place_name)""")
                         
        c.execute('''INSERT INTO tweets 
        (created_at, favorite_count, favorited, filter_level, lang, 
                         retweet_count, retweeted, source, text, truncated, user_created_at,  
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ) 
            VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)''', 
            (created_at, favorite_count, favorited, filter_level, lang, retweet_count, 
                         retweeted, source, text, truncated, user_created_at, 
                         user_followers_count, user_location, user_lang, user_name, 
                         user_screen_name, user_time_zone, user_friends_count,geo_enabled,coordinates,geo,place_name ))
        conn.commit()
        conn.close()
    
            
if __name__ == '__main__':
    
    hash_tag_list = ['mumbai']
    fetched_tweets_filename = "tweets.json"
    
    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
    
#     listener = StdOutListener()
#     auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
#     auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
    
#     stream = Stream(auth, listener)
    
#     stream.filter(track=['akshay kumar'])
# Out:
# {'created_at': 'Fri Mar 20 19:35:51 +0000 2020', 'id': 1241086069539508225, 'id_str': '1241086069539508225', 'text': "Patience is not simply the ability to wait....It's how we behave while we're waiting...! @ Mumbai, Maharashtra https://t.co/5GDOPboN30", 'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1206243236739551232, 'id_str': '1206243236739551232', 'name': 'mahirR', 'screen_name': 'mahirR39632021', 'location': None, 'url': None, 'description': 'Actor in different characters!', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 7, 'friends_count': 12, 'listed_count': 0, 'favourites_count': 19, 'statuses_count': 24, 'created_at': 'Sun Dec 15 16:03:11 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1206243389827469312/wZKaoIQK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1206243389827469312/wZKaoIQK_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/5GDOPboN30', 'expanded_url': 'https://www.instagram.com/p/B996dtIFHea/?igshid=1ffk633px3rvq', 'display_url': 'instagram.com/p/B996dtIFHea/…', 'indices': [111, 134]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1584732951899'}
# {'created_at': 'Fri Mar 20 19:35:58 +0000 2020', 'id': 1241086098681384961, 'id_str': '1241086098681384961', 'text': "RT @MumbaiMirror: #WATCH: Thousands of people have congregated at Mumbai's railway stations to board trains taking them back to their respe…", 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 984632976, 'id_str': '984632976', 'name': 'Ramasya Dasosmyaham', 'screen_name': 'PitchumaniH', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 310, 'friends_count': 1054, 'listed_count': 1, 'favourites_count': 125370, 'statuses_count': 108092, 'created_at': 'Sun Dec 02 13:38:03 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000843667136/3a1a84f9139791ae6a71ac4883059411_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000843667136/3a1a84f9139791ae6a71ac4883059411_normal.jpeg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 20 17:14:31 +0000 2020', 'id': 1241050499706548224, 'id_str': '1241050499706548224', 'text': "#WATCH: Thousands of people have congregated at Mumbai's railway stations to board trains taking them back to their… https://t.co/ksMlRvZf8B", 'display_text_range': [0, 140], 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 990761677, 'id_str': '990761677', 'name': 'Mumbai Mirror', 'screen_name': 'MumbaiMirror', 'location': 'Mumbai, India', 'url': 'https://mumbaimirror.indiatimes.com', 'description': "India's largest compact newspaper.", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 304393, 'friends_count': 226, 'listed_count': 363, 'favourites_count': 342, 'statuses_count': 60052, 'created_at': 'Wed Dec 05 11:37:45 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'D8261C', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'D92B22', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/602018423887953920/JxUnVH5l_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/602018423887953920/JxUnVH5l_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/990761677/1584679943', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates' ...
# {'created_at': 'Fri Mar 20 19:36:01 +0000 2020', 'id': 1241086111574896640, 'id_str': '1241086111574896640', 'text': "RT @ketanchiplunkar: @tech_mahindra Why u r not following guidelines given by Government? What's the problem? In Mumbai, Pune everywhere ur…", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 165169145, 'id_str': '165169145', 'name': 'Jenson DSouza', 'screen_name': 'jenson_dj', 'location': 'Mumbai', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 144, 'friends_count': 917, 'listed_count': 10, 'favourites_count': 2884, 'statuses_count': 5072, 'created_at': 'Sat Jul 10 20:18:08 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/795265268213813254/JnRrStmk_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/795265268213813254/JnRrStmk_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/165169145/1478440992', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 20 19:14:59 +0000 2020', 'id': 1241080816966332416, 'id_str': '1241080816966332416', 'text': "@tech_mahindra Why u r not following guidelines given by Government? What's the problem? In Mumbai, Pune everywhere… https://t.co/ToK8dTmr55", 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 51406202, 'in_reply_to_user_id_str': '51406202', 'in_reply_to_screen_name': 'tech_mahindra', 'user': {'id': 97706515, 'id_str': '97706515', 'name': 'Ketan Chiplunkar', 'screen_name': 'ketanchiplunkar', 'location': 'Mumbai, India', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 8, 'friends_count': 15, 'listed_count': 0, 'favourites_count': 0, 'statuses_count': 33, 'created_at': 'Fri Dec 18 16:59:29 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1241083139633512450/utzV9SN7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1241083139633512450/utzV9SN7_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_t ...
# {'created_at': 'Fri Mar 20 19:36:06 +0000 2020', 'id': 1241086130943963136, 'id_str': '1241086130943963136', 'text': 'RT @jitengajaria: The below tweet &amp; this video from LTT in Kurla. Exodus of mainly daily wage earners. @OfficeofUT should have announced a…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3244475336, 'id_str': '3244475336', 'name': 'Nachiket Sahasrabudhe #iAmSavarkar', 'screen_name': 'Nachikaait24', 'location': 'Pune, India', 'url': None, 'description': 'artist , common man ,', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 210, 'friends_count': 418, 'listed_count': 0, 'favourites_count': 8081, 'statuses_count': 3216, 'created_at': 'Sat Jun 13 18:57:03 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1235927610812542976/jjZxcWSi_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235927610812542976/jjZxcWSi_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3244475336/1527618939', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 20 19:33:40 +0000 2020', 'id': 1241085517258612736, 'id_str': '1241085517258612736', 'text': 'The below tweet &amp; this video from LTT in Kurla. Exodus of mainly daily wage earners. @OfficeofUT should have announ… https://t.co/ayPkuBLqvc', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 105130840, 'id_str': '105130840', 'name': 'Jiten Gajaria', 'screen_name': 'jitengajaria', 'location': 'India', 'url': 'http://greatindiandemocracy.blogspot.com', 'description': 'Nomad by heart and politician by choice.\nTweets are personal views', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 12691, 'friends_count': 1555, 'listed_count': 141, 'favourites_count': 1486, 'statuses_count': 81654, 'created_at': 'Fri Jan 15 12:59:30 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1236887612104687624/YLWjVix-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1236887612104687624/YLWjVix-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/105130840/1562773008', 'default_profile': True, ...
# {'created_at': 'Fri Mar 20 19:36:06 +0000 2020', 'id': 1241086132256899072, 'id_str': '1241086132256899072', 'text': 'RT @AUThackeray: CM Uddhav Thackeray announces that from this Midnight, all workplaces will remain closed till 31st March. \nThis is applica…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 89198300, 'id_str': '89198300', 'name': 'फरhaن Mumbaikar فرحان ممبئکر', 'screen_name': 'FarhanM80', 'location': 'Columbus, OH', 'url': None, 'description': 'सभी का ख़ून है शामिल यहाँ की मिट्टी में, किसी के बाप का हिन्दोस्तान थोड़ी है...', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 142, 'friends_count': 381, 'listed_count': 2, 'favourites_count': 33671, 'statuses_count': 26182, 'created_at': 'Wed Nov 11 14:40:31 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1184279005505167360/Z7w5AhjA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1184279005505167360/Z7w5AhjA_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/89198300/1464451207', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 20 08:13:23 +0000 2020', 'id': 1240914317542715392, 'id_str': '1240914317542715392', 'text': 'CM Uddhav Thackeray announces that from this Midnight, all workplaces will remain closed till 31st March. \nThis is… https://t.co/gCaLPiKOZK', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1606048885, 'id_str': '1606048885', 'name': 'Aaditya Thackeray', 'screen_name': 'AUThackeray', 'location': None, 'url': None, 'description': 'Voicing the Youth, Poems and Photography: Passion. President, Yuva Sena. President- Mumbai District Football Association Instagram: adityathackeray', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 2097774, 'friends_count': 842, 'listed_count': 580, 'favourites_count': 6192, 'statuses_count': 9726, 'created_at': 'Fri Jul 19 14:15:30 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1218435318845755392/ucNA9yjF_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1218435318845755392/ucNA9yjF_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1 ...
# {'created_at': 'Fri Mar 20 19:36:07 +0000 2020', 'id': 1241086133527703553, 'id_str': '1241086133527703553', 'text': 'RT @Sootradhar: Bombay High Court to Govt of Maharashtra\n\nWhy masses on in Catholic churches? \n\nThey are even distributing holy communion d…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1115127117715525632, 'id_str': '1115127117715525632', 'name': 'Bayleybuddyrin', 'screen_name': 'bayleybuddyrin3', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 173, 'friends_count': 78, 'listed_count': 0, 'favourites_count': 48536, 'statuses_count': 19340, 'created_at': 'Mon Apr 08 05:39:57 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1115127532825796609/BKwo6fgY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115127532825796609/BKwo6fgY_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1115127117715525632/1554896457', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 20 03:03:12 +0000 2020', 'id': 1240836257283837953, 'id_str': '1240836257283837953', 'text': 'Bombay High Court to Govt of Maharashtra\n\nWhy masses on in Catholic churches? \n\nThey are even distributing holy com… https://t.co/BStYzcGuuE', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18304860, 'id_str': '18304860', 'name': 'Jiggs', 'screen_name': 'Sootradhar', 'location': 'India', 'url': 'https://youtu.be/iGWqGtPFbDQ', 'description': '|| सत्यमेव जयते ||', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 50764, 'friends_count': 3040, 'listed_count': 358, 'favourites_count': 3210, 'statuses_count': 457658, 'created_at': 'Mon Dec 22 10:41:29 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFF04D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': False, 'profile_link_color': '0099CC', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F6FFD1', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1239057520397676545/iYk7TUT__normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1239057520397676545/iYk7TUT__normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18304860/1579691276', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_twe ...
# {'created_at': 'Fri Mar 20 19:36:07 +0000 2020', 'id': 1241086133993213952, 'id_str': '1241086133993213952', 'text': 'RT @ShefVaidya: Hi @OfficeofUT you announced a lockdown of Mumbai, Pune Nagpur. Being law abiding citizens, we Hindus comply, but what abou…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1152836242096005120, 'id_str': '1152836242096005120', 'name': 'Praful', 'screen_name': 'Praful18099300', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 24, 'friends_count': 222, 'listed_count': 0, 'favourites_count': 3926, 'statuses_count': 7026, 'created_at': 'Sun Jul 21 07:02:33 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1224719737885560832/UltjjUyb_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1224719737885560832/UltjjUyb_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 20 12:36:08 +0000 2020', 'id': 1240980444021059588, 'id_str': '1240980444021059588', 'text': 'Hi @OfficeofUT you announced a lockdown of Mumbai, Pune Nagpur. Being law abiding citizens, we Hindus comply, but w… https://t.co/eCWzdHZzoS', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1934388686, 'id_str': '1934388686', 'name': 'Shefali Vaidya.', 'screen_name': 'ShefVaidya', 'location': 'Pune, Maharashtra', 'url': 'http://swarajyamag.com/author/17642/shefali-vaidya', 'description': 'Author, Satirist, Speaker. Fellow-Ananta Leadership Program, Convenor-Indic Academy. Love Travel, Temples And Textiles. Mum to triplets. Indian. Hindu. Woman', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 462940, 'friends_count': 2229, 'listed_count': 689, 'favourites_count': 51253, 'statuses_count': 98235, 'created_at': 'Fri Oct 04 14:09:56 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C6E2EE', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1F98C7', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1237579876686684168/phfQ5nLx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1237579876686684168/phfQ5nLx_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1934388686/1549272762', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'p ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a4e9b6fa4471> in <module>
#      91
#      92     twitter_streamer = TwitterStreamer()
# ---> 93     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#      94
#      95 #     listener = StdOutListener()
#
# <ipython-input-3-a4e9b6fa4471> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      18         stream = Stream(auth, listener)
#      19
# ---> 20         stream.filter(track=['Mumbai'])
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy-3.8.0-py3.6.egg\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     491
#     492         if self.chunked:
# --> 493             return self._readinto_chunked(b)
#     494
#     495         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     586         try:
#     587             while True:
# --> 588                 chunk_left = self._get_chunk_left()
#     589                 if chunk_left is None:
#     590                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     554                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     555             try:
# --> 556                 chunk_left = self._read_next_chunk_size()
#     557             except ValueError:
#     558                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     514     def _read_next_chunk_size(self):
#     515         # Read the next chunk size from the file
# --> 516         line = self.fp.readline(_MAXLINE + 1)
#     517         if len(line) > _MAXLINE:
#     518             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:

# %%
import tweepy
auth = OAuthHandler(credentials.CONSUMER_KEY, credentials.CONSUMER_SECRET)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)
public_tweets = api.home_timeline(tweet_mode='extended')
# foreach through all tweets pulled
for tweet in public_tweets:
   # printing the text stored inside the tweet object
   print(tweet.full_text)
# Out:
# Tech Talks #1082 - Realme NARZO 10 Launch 26 Mar, K30Pro Camera, BSNL Free Broadband, Fold 2 https://t.co/gqSeY6Qlj1 via @YouTubeIndia
# RT @WVFRM: New Episode! The New iPad Pro + Magic Keyboard rants and #QuarantineContent to Keep You Entertained!
#
# Listen anywhere: https://t…
# NEW VIDEO - 2020 MacBook Air Impressions: A Clean Refresh! https://t.co/dsBVgqzra9 - RT! https://t.co/qnI0j8IZ75
# How bout a new video in exactly 12 minutes? 🍎
# Finally got the Samsung Galaxy S20 Ultra. I'll post the unboxing &amp; overview video tomorrow. https://t.co/CdlKJK4MdJ
# RT @AndyManganelli: If you all liked the @dbrand plug from our S20 video, thought you might like a few of the outtakes (this isn't even all…
# No Storage On Internet??? Internet Storage Capacity??? Storage Full!!!🔥🔥🔥 https://t.co/45j5yEG8YO via @YouTubeIndia
# One of the better video on Coronavirus with facts https://t.co/gRlAHj8Zd4
#
# Take care and we as citizens are youngsters have to be careful and not to spread it in India, as we are still in stage 2 for now and hope it does not develop like what we are seeing in Italy.
# iQ00 3 vs OnePlus 7T Smartphone Practical Comparison https://t.co/j07WyPyHay @YouTubeIndia
# If there were some kind of world records, then Realme &amp; Xiaomi (Redmi) would be the top candidates for amount of smartphones models launched in a given year.
#
# These Companies are not done yet, expect more launches by the month end.
#
# It was insanity, but now pure madness!
# @_KaProductions @FuhSePhantom @NGEMovies @vibri_media @ZeeMusicCompany @PicturesPVR @83thefilm
# 83 is not just our film but the entire nation’s film. But the health and safety of the nation always comes first. Stay safe, take care.
# We shall be back soon!
# .
# @kabirkhankk @deepikapadukone @Shibasishsarkar #SajidNadiadwala @vishinduri @ipritamofficial @RelianceEnt https://t.co/wS0Anl8BM2
# Finally...
# Tech Talks #1081 - Realme NARZO Series, Mi 10 India Launch, Honor 30s, Galaxy A41, Sony PS5 Launch https://t.co/rxZj6y0Axs via @YouTubeIndia
# Real talk though, I'm grateful to have a job I can still do solo in trying times like this. Hang tight and there's some #quarantinecontent coming your way shortly
#
# In the meantime, watch this excellent @Kurz_Gesagt video: https://t.co/rS3MhIidK2
# Happy First Day of Spring! Today’s a great day for spring cleaning… of your hands.
# RT @Kurz_Gesagt: NEW VIDEO: The Coronavirus Explained &amp; What You Should Do
#
# https://t.co/UEmWSsJNfw
# Home alone. Day 2
# Socha Rafi sahab ka gaana gunguna loon 🙂
# #BBacoustic https://t.co/PdIJIG4yi1
# Realme NARZO Smartphone Series - Better Than POCO and REDMI??? Best Deal From Realme🔥🔥🔥 https://t.co/68uQaRZd4i via @YouTubeIndia #RealmeNarzo
# Got this one in the mailer, looks like the GST effect of 18% slab on mobiles is starting from 1st April 2020 onwards. https://t.co/qXLthqN7LH
